# %%
def markov_dict():
  # defining a function
    word_freqs = {}
    # setting an empty dictionary for word frequencies
    with open("sonnets.txt", "r") as file_object:
        # reading our input file
        past_word = ""
        # setting past_word to an empty string
        for line in file_object:
            line_split = line.split()
          # looping over each line in our input file
            curr_word = " ".join(line_split)
            # splitting each line into individual words
            if past_word in word_freqs:
              # checking if the past word exists
                frequency = word_freqs[past_word]
                # if exists, assign it to our dictionary
            else:
                frequency = {}
                # if it doesn't exist add it with a new key to our dictionary
                word_freqs[past_word] = frequency
            if curr_word in frequency:
              # if exists assign the value as current word in frequency dict
                occ = frequency[curr_word]
            else:
              # if not, assign 0 to occurrences
                occ = 0
            frequency[curr_word] = 1
            # increment current word + 1
            past_word = curr_word
            # update past_word to the current word we're on
        return word_freqs
        # return the word frequencies dictionary

# %%
markov_dict()
# Out:
# {'': {'Those hours, that with gentle work did frame': 1,
#   'Then let not winter’s ragged hand deface,': 1,
#   'Look in thy glass, and tell the face thou viewest': 1,
#   'Unthrifty loveliness, why dost thou spend': 1,
#   'Weary with toil, I haste me to my bed,': 1,
#   'Music to hear, why hear’st thou music sadly?': 1,
#   'Is it for fear to wet a widow’s eye,': 1,
#   'For shame deny that thou bear’st love to any,': 1},
#  'Those hours, that with gentle work did frame': {'The lovely gaze where every eye doth dwell,': 1},
#  'The lovely gaze where every eye doth dwell,': {'Will play the tyrants to the very same': 1},
#  'Will play the tyrants to the very same': {'And that unfair which fairly doth excel;': 1},
#  'And that unfair which fairly doth excel;': {'For never-resting time leads summer on': 1},
#  'For never-resting time leads summer on': {'To hideous winter, and confounds him there;': 1},
#  'To hideous winter, and confounds him there;': {'Sap checked with frost, and lusty leaves quite gone,': 1},
#  'Sap checked with frost, and lusty leaves quite gone,': {'Beauty o’er-snowed and bareness every where:': 1},
#  'Beauty o’er-snowed and bareness every where:': {'Then were not summer’s distillation left,': 1},
#  'Then were not summer’s distillation left,': {'A liquid prisoner pent in walls of glass,': 1},
#  'A liquid prisoner pent in walls of glass,': {'Beauty’s effect with beauty were bereft,': 1},
#  'Beauty’s effect with beauty were bereft,': {'Nor it, nor no remembrance what it was:': 1},
#  'Nor it, nor no remembrance what it was:': {'But flowers distill’d, though they with winter meet,': 1},
#  'But flowers distill’d, though they with winter meet,': {'Leese but their show; their substance still lives sweet.': 1},
#  'Leese but their show; their substance still lives sweet.': {'': 1},
#  'Then let not winter’s ragged hand deface,': {'In thee thy summer, ere thou be distilled:': 1},
#  'In thee thy summer, ere thou be distilled:': {'Make sweet some vial; treasure thou some place': 1},
#  'Make sweet some vial; treasure thou some place': {'With beauty’s treasure ere it be self-killed.': 1},
#  'With beauty’s treasure ere it be self-killed.': {'That use is not forbidden usury,': 1},
#  'That use is not forbidden usury,': {'Which happies those that pay the willing loan;': 1},
#  'Which happies those that pay the willing loan;': {'That’s for thy self to breed another thee,': 1},
#  'That’s for thy self to breed another thee,': {'Or ten times happier, be it ten for one;': 1},
#  'Or ten times happier, be it ten for one;': {'Ten times thy self were happier than thou art,': 1},
#  'Ten times thy self were happier than thou art,': {'If ten of thine ten times refigured thee:': 1},
#  'If ten of thine ten times refigured thee:': {'Then what could death do if thou shouldst depart,': 1},
#  'Then what could death do if thou shouldst depart,': {'Leaving thee living in posterity?': 1},
#  'Leaving thee living in posterity?': {'Be not self-willed, for thou art much too fair': 1},
#  'Be not self-willed, for thou art much too fair': {'To be death’s conquest and make worms thine heir.': 1},
#  'To be death’s conquest and make worms thine heir.': {'': 1},
#  'Look in thy glass, and tell the face thou viewest': {'Now is the time that face should form another;': 1},
#  'Now is the time that face should form another;': {'Whose fresh repair if now thou not renewest,': 1},
#  'Whose fresh repair if now thou not renewest,': {'Thou dost beguile the world, unbless some mother.': 1},
#  'Thou dost beguile the world, unbless some mother.': {'For where is she so fair whose unear’d womb': 1},
#  'For where is she so fair whose unear’d womb': {'Disdains the tillage of thy husbandry?': 1},
#  'Disdains the tillage of thy husbandry?': {'Or who is he so fond will be the tomb': 1},
#  'Or who is he so fond will be the tomb': {'Of his self-love, to stop posterity?': 1},
#  'Of his self-love, to stop posterity?': {'Thou art thy mother’s glass, and she in thee': 1},
#  'Thou art thy mother’s glass, and she in thee': {'Calls back the lovely April of her prime:': 1},
#  'Calls back the lovely April of her prime:': {'So thou through windows of thine age shall see': 1},
#  'So thou through windows of thine age shall see': {'Despite of wrinkles this thy golden time.': 1},
#  'Despite of wrinkles this thy golden time.': {'But if thou live, remember’d not to be,': 1},
#  'But if thou live, remember’d not to be,': {'Die single, and thine image dies with thee.': 1},
#  'Die single, and thine image dies with thee.': {'': 1},
#  'Unthrifty loveliness, why dost thou spend': {'Upon thyself thy beauty’s legacy?': 1},
#  'Upon thyself thy beauty’s legacy?': {'Nature’s bequest gives nothing but doth lend,': 1},
#  'Nature’s bequest gives nothing but doth lend,': {'And being frank she lends to those are free.': 1},
#  'And being frank she lends to those are free.': {'Then, beauteous niggard, why dost thou abuse': 1},
#  'Then, beauteous niggard, why dost thou abuse': {'The bounteous largess given thee to give?': 1},
#  'The bounteous largess given thee to give?': {'Profitless usurer, why dost thou use': 1},
#  'Profitless usurer, why dost thou use': {'So great a sum of sums, yet canst not live?': 1},
#  'So great a sum of sums, yet canst not live?': {'For having traffic with thyself alone,': 1},
#  'For having traffic with thyself alone,': {'Thou of thyself thy sweet self dost deceive.': 1},
#  'Thou of thyself thy sweet self dost deceive.': {'Then how, when nature calls thee to be gone,': 1},
#  'Then how, when nature calls thee to be gone,': {'What acceptable audit canst thou leave?': 1},
#  'What acceptable audit canst thou leave?': {'Thy unused beauty must be tomb’d with thee,': 1},
#  'Thy unused beauty must be tomb’d with thee,': {'Which, used, lives th’ executor to be.': 1},
#  'Which, used, lives th’ executor to be.': {'': 1},
#  'Weary with toil, I haste me to my bed,': {'The dear repose for limbs with travel tired;': 1},
#  'The dear repose for limbs with travel tired;': {'But then begins a journey in my head': 1},
#  'But then begins a journey in my head': {'To work my mind, when body’s work’s expired:': 1},
#  'To work my mind, when body’s work’s expired:': {'For then my thoughts–from far where I abide–': 1},
#  'For then my thoughts–from far where I abide–': {'Intend a zealous pilgrimage to thee,': 1},
#  'Intend a zealous pilgrimage to thee,': {'And keep my drooping eyelids open wide,': 1},
#  'And keep my drooping eyelids open wide,': {'Looking on darkness which the blind do see:': 1},
#  'Looking on darkness which the blind do see:': {'Save that my soul’s imaginary sight': 1},
#  'Save that my soul’s imaginary sight': {'Presents thy shadow to my sightless view,': 1},
#  'Presents thy shadow to my sightless view,': {'Which, like a jewel hung in ghastly night,': 1},
#  'Which, like a jewel hung in ghastly night,': {'Makes black night beauteous, and her old face new.': 1},
#  'Makes black night beauteous, and her old face new.': {'Lo! thus, by day my limbs, by night my mind,': 1},
#  'Lo! thus, by day my limbs, by night my mind,': {'For thee, and for myself, no quiet find.': 1},
#  'For thee, and for myself, no quiet find.': {'': 1},
#  'Music to hear, why hear’st thou music sadly?': {'Sweets with sweets war not, joy delights in joy:': 1},
#  'Sweets with sweets war not, joy delights in joy:': {'Why lov’st thou that which thou receiv’st not gladly,': 1},
#  'Why lov’st thou that which thou receiv’st not gladly,': {'Or else receiv’st with pleasure thine annoy?': 1},
#  'Or else receiv’st with pleasure thine annoy?': {'If the true concord of well-tuned sounds,': 1},
#  'If the true concord of well-tuned sounds,': {'By unions married, do offend thine ear,': 1},
#  'By unions married, do offend thine ear,': {'They do but sweetly chide thee, who confounds': 1},
#  'They do but sweetly chide thee, who confounds': {'In singleness the parts that thou shouldst bear.': 1},
#  'In singleness the parts that thou shouldst bear.': {'Mark how one string, sweet husband to another,': 1},
#  'Mark how one string, sweet husband to another,': {'Strikes each in each by mutual ordering;': 1},
#  'Strikes each in each by mutual ordering;': {'Resembling sire and child and happy mother,': 1},
#  'Resembling sire and child and happy mother,': {'Who, all in one, one pleasing note do sing:': 1},
#  'Who, all in one, one pleasing note do sing:': {'Whose speechless song being many, seeming one,': 1},
#  'Whose speechless song being many, seeming one,': {'Sings this to thee: ‘Thou single wilt prove none.’': 1},
#  'Sings this to thee: ‘Thou single wilt prove none.’': {'': 1},
#  'Is it for fear to wet a widow’s eye,': {'That thou consum’st thy self in single life?': 1},
#  'That thou consum’st thy self in single life?': {'Ah! if thou issueless shalt hap to die,': 1},
#  'Ah! if thou issueless shalt hap to die,': {'The world will wail thee like a makeless wife;': 1},
#  'The world will wail thee like a makeless wife;': {'The world will be thy widow and still weep': 1},
#  'The world will be thy widow and still weep': {'That thou no form of thee hast left behind,': 1},
#  'That thou no form of thee hast left behind,': {'When every private widow well may keep': 1},
#  'When every private widow well may keep': {'By children’s eyes, her husband’s shape in mind:': 1},
#  'By children’s eyes, her husband’s shape in mind:': {'Look what an unthrift in the world doth spend': 1},
#  'Look what an unthrift in the world doth spend': {'Shifts but his place, for still the world enjoys it;': 1},
#  'Shifts but his place, for still the world enjoys it;': {'But beauty’s waste hath in the world an end,': 1},
#  'But beauty’s waste hath in the world an end,': {'And kept unused the user so destroys it.': 1},
#  'And kept unused the user so destroys it.': {'No love toward others in that bosom sits': 1},
#  'No love toward others in that bosom sits': {'That on himself such murd’rous shame commits.': 1},
#  'That on himself such murd’rous shame commits.': {'': 1},
#  'For shame deny that thou bear’st love to any,': {'Who for thy self art so unprovident.': 1},
#  'Who for thy self art so unprovident.': {'Grant, if thou wilt, thou art beloved of many,': 1},
#  'Grant, if thou wilt, thou art beloved of many,': {'But that thou none lov’st is most evident:': 1},
#  'But that thou none lov’st is most evident:': {'For thou art so possessed with murderous hate,': 1},
#  'For thou art so possessed with murderous hate,': {'That ‘gainst thy self thou stick’st not to conspire,': 1},
#  'That ‘gainst thy self thou stick’st not to conspire,': {'Seeking that beauteous roof to ruinate': 1},
#  'Seeking that beauteous roof to ruinate': {'Which to repair should be thy chief desire.': 1},
#  'Which to repair should be thy chief desire.': {'O! change thy thought, that I may change my mind:': 1},
#  'O! change thy thought, that I may change my mind:': {'Shall hate be fairer lodged than gentle love?': 1},
#  'Shall hate be fairer lodged than gentle love?': {'Be, as thy presence is, gracious and kind,': 1},
#  'Be, as thy presence is, gracious and kind,': {'Or to thyself at least kind-hearted prove:': 1},
#  'Or to thyself at least kind-hearted prove:': {'Make thee another self for love of me,': 1},
#  'Make thee another self for love of me,': {'That beauty still may live in thine or thee.': 1}}
