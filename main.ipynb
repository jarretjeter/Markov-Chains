# %%
def markov_dict():
  # defining a function
    word_freqs = {}
    # setting an empty dictionary for word frequencies
    with open("sonnets.txt", "r") as file_object:
        # reading our input file
        past_word = ""
        # setting past_word to an empty string
        for line in file_object:
            line_split = line.split()
          # looping over each line in our input file
            for curr_word in line_split:
                # splitting each line into individual words
                if past_word in word_freqs:
                  # checking if the past word exists
                    frequency = word_freqs[past_word]
                    # if exists, assign it to our dictionary
                else:
                    frequency = {}
                    # if it doesn't exist add it with a new key to our dictionary
                    word_freqs[past_word] = frequency
                if curr_word in frequency:
                  # if exists increment the value by 1
                    frequency[curr_word] += 1
                else:
                  # if not, assign value to 1
                    frequency[curr_word] = 1
                    
                past_word = curr_word
                # update past_word to the current word we're on
        # del word_freqs[" "]
        return word_freqs
        # return the word frequencies dictionary

# %%
markov_dict()
# Out:
# {'': {'Those': 1},
#  'Those': {'hours,': 1},
#  'hours,': {'that': 1},
#  'that': {'with': 1,
#   'unfair': 1,
#   'pay': 1,
#   'face': 1,
#   'my': 1,
#   'which': 1,
#   'thou': 3,
#   'bosom': 1,
#   'beauteous': 1,
#   'I': 1},
#  'with': {'gentle': 1,
#   'frost,': 1,
#   'beauty': 1,
#   'winter': 1,
#   'thee.': 1,
#   'thyself': 1,
#   'thee,': 1,
#   'toil,': 1,
#   'travel': 1,
#   'sweets': 1,
#   'pleasure': 1,
#   'murderous': 1},
#  'gentle': {'work': 1, 'love?': 1},
#  'work': {'did': 1, 'my': 1},
#  'did': {'frame': 1},
#  'frame': {'The': 1},
#  'The': {'lovely': 1, 'bounteous': 1, 'dear': 1, 'world': 2},
#  'lovely': {'gaze': 1, 'April': 1},
#  'gaze': {'where': 1},
#  'where': {'every': 1, 'is': 1, 'I': 1},
#  'every': {'eye': 1, 'where:': 1, 'private': 1},
#  'eye': {'doth': 1},
#  'doth': {'dwell,': 1, 'excel;': 1, 'lend,': 1, 'spend': 1},
#  'dwell,': {'Will': 1},
#  'Will': {'play': 1},
#  'play': {'the': 1},
#  'the': {'tyrants': 1,
#   'very': 1,
# ...

# %%
def markov_chain():
    input_dict = markov_dict()
    print(input_dict)
    total = 0
    for key in input_dict:
        for subkey in key: 
            total = 

markov_chain()
# Out:
# {'': {'Those': 1}, 'Those': {'hours,': 1}, 'hours,': {'that': 1}, 'that': {'with': 1, 'unfair': 1, 'pay': 1, 'face': 1, 'my': 1, 'which': 1, 'thou': 3, 'bosom': 1, 'beauteous': 1, 'I': 1}, 'with': {'gentle': 1, 'frost,': 1, 'beauty': 1, 'winter': 1, 'thee.': 1, 'thyself': 1, 'thee,': 1, 'toil,': 1, 'travel': 1, 'sweets': 1, 'pleasure': 1, 'murderous': 1}, 'gentle': {'work': 1, 'love?': 1}, 'work': {'did': 1, 'my': 1}, 'did': {'frame': 1}, 'frame': {'The': 1}, 'The': {'lovely': 1, 'bounteous': 1, 'dear': 1, 'world': 2}, 'lovely': {'gaze': 1, 'April': 1}, 'gaze': {'where': 1}, 'where': {'every': 1, 'is': 1, 'I': 1}, 'every': {'eye': 1, 'where:': 1, 'private': 1}, 'eye': {'doth': 1}, 'doth': {'dwell,': 1, 'excel;': 1, 'lend,': 1, 'spend': 1}, 'dwell,': {'Will': 1}, 'Will': {'play': 1}, 'play': {'the': 1}, 'the': {'tyrants': 1, 'very': 1, 'willing': 1, 'face': 1, 'time': 1, 'world,': 1, 'tillage': 1, 'tomb': 1, 'lovely': 1, 'blind': 1, 'true': 1, 'parts': 1, 'world': 3, 'user': 1}, 'tyra
# ...
